# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
plt.style.use('seaborn')

# %matplotlib inline

# %%
#Importing data from the well header worksheet
well_header=pd.read_csv('WellHeader_Datathon_edited.csv')
# Out:
# C:\Users\cheta\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning:
#
# Columns (24,26,27,28,52,54,55,56,80,81) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
well_header.head()
# Out:
#    EPAssetsId Province LicenceNumber               UWI       CurrentOperator  \
# 0     2587301  Alberta        475898  100122706624W500  Enerplus Corporation
# 1     2593278  Alberta        479407  102052706624W500  Enerplus Corporation
# 2     2579437  Alberta        469132  100162206624W500  Enerplus Corporation
# 3     2591761  Alberta        478708  100092206624W500  Enerplus Corporation
# 4     2587302  Alberta        475923  100082206624W500  Enerplus Corporation
#
#    CurrentOperatorParent CurrentOperatorParentName              Licensee  \
# 0                    267      Enerplus Corporation  Enerplus Corporation
# 1                    267      Enerplus Corporation  Enerplus Corporation
# 2                    267      Enerplus Corporation  Enerplus Corporation
# 3                    267      Enerplus Corporation  Enerplus Corporation
# 4                    267      Enerplus Corporation  Enerplus Corporation
#
#    LicenseeParentCompany LicenseeParentCompanyName  ... StatusSource UnitID  \
# 0                    267      Enerplus Corporation  ...          AER    NaN
# 1                    267      Enerplus Corporation  ...          AER    NaN
# 2                    267      Enerplus Corporation  ...          AER    NaN
# 3                    267      Enerplus Corporation  ...          AER    NaN
# 4                    267      Enerplus Corporation  ...          AER    NaN
#
#   UnitName UnitFlag Municipality CompletionDate        Agent  _Completed`Flag  \
# 0      NaN       No          NaN            NaN  Unspecified                1
# 1      NaN       No          NaN            NaN  Unspecified                1
# 2      NaN       No          NaN            NaN  Unspecified                1
# 3      NaN       No          NaN            NaN  Unspecified                1
# 4      NaN       No          NaN            NaN  Unspecified                1
#
#   _Perf`Flag Match
# 0          1   Yes
# 1          1   Yes
# 2          1   Yes
# 3          1   Yes
# 4          1   Yes
#
# [5 rows x 89 columns]

# %%
well_header.describe().transpose()
# Out:
#                          count          mean            std          min  \
# EPAssetsId             10436.0  1.609559e+06  960903.274006  3373.000000
# CurrentOperatorParent  10436.0  1.990939e+03    2719.980325    16.000000
# LicenseeParentCompany  10436.0  1.999133e+03    2725.435780    16.000000
# AbandonDate                0.0           NaN            NaN          NaN
# SurfAbandonDate            0.0           NaN            NaN          NaN
# Surf_Longitude         10436.0 -1.138207e+02       6.242177  -122.939258
# Surf_Latitude          10436.0  5.320227e+01       2.609611     0.000000
# BH_Longitude            8696.0 -1.125419e+02       4.094611  -119.999593
# BH_Latitude             8696.0  5.266497e+01       1.430057    49.964650
# GroundElevation        10428.0  7.852791e+02     157.422631   565.200000
# KBElevation            10436.0  7.896813e+02     130.280649   569.800000
# TotalDepth             10436.0  3.235640e+03    1641.376879   888.000000
# DaysDrilling           10430.0  1.857306e+01      32.523967     0.000000
# DrillMetresPerDay      10436.0  6.260237e+02     516.940323     0.000000
# TVD                     6730.0  1.419685e+03     913.760530   575.440000
# ProjectedDepth         10044.0  2.796034e+03    2052.077284   460.000000
# _Completed`Flag        10436.0  1.000000e+00       0.000000     1.000000
# _Perf`Flag             10436.0  1.000000e+00       0.000000     1.000000
#
#                                 25%           50%           75%           max
# EPAssetsId             1.159959e+06  1.171592e+06  2.602619e+06  2.625908e+06
# CurrentOperatorParent  2.470000e+02  1.187000e+03  1.613000e+03  9.901000e+03
# LicenseeParentCompany  2.470000e+02  1.187000e+03  1.613000e+03  9.901000e+03
# AbandonDate                     NaN           NaN           NaN           NaN
# SurfAbandonDate                 NaN           NaN           NaN           NaN
# Surf_Longitude        -1.187265e+02 -1.134081e+02 -1.090770e+02  0.000000e+00
# Surf_Latitude          5.161127e+01  5.229285e+01  5.477499e+01  5.752191e+01
# BH_Longitude          -1.169032e+02 -1.104889e+02 -1.089319e+02 -1.077269e+02
# BH_Latitude            5.156799e+01  5.192357e+01  5.422217e+01  5.658039e+01
# GroundElevation        6.941000e+02  7.271000e+02  8.597000e+02  9.914000e+03
# KBElevation            6.984000e+02  7.332000e+02  8.660000e+02  1.377000e+03
# TotalDepth             1.599912e+03  2.586000e+03  4.583250e+03  7.848000e+03
# DaysDrilling           2.000000e+00  8.000000e+00  2.000000e+01  7.380000e+02
# DrillMetresPerDay      2.098900e+02  4.573500e+02  9.012500e+02  2.655000e+03
# TVD                    7.114850e+02  7.662850e+02  2.206775e+03  4.366000e+03
# ProjectedDepth         7.200000e+02  2.400000e+03  4.542150e+03  7.550000e+03
# _Completed`Flag        1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# _Perf`Flag             1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00

# %%
well_header.isnull().sum()
# Out:
# EPAssetsId            0
# Province              0
# LicenceNumber         0
# UWI                   0
# CurrentOperator       0
#                    ...
# CompletionDate     4586
# Agent                 0
# _Completed`Flag       0
# _Perf`Flag            0
# Match                 0
# Length: 89, dtype: int64

# %%
well_cut=well_header[well_header.Formation!='Cardium']

# %%
outlier=well_cut[['EPAssetsId','TotalDepth', 'TVD']]

# %%
outlier=outlier[outlier.TVD.notnull()]

# %%
outlier_data=pd.DataFrame(outlier.iloc[:,1:])
outlier_data
# Out:
#        TotalDepth      TVD
# 1          3607.0  1954.58
# 2          3502.0  1940.06
# 3          3491.0  1945.01
# 4          3578.0  1956.34
# 5          3659.0  1911.62
# ...           ...      ...
# 10425      2024.0   891.82
# 10428      2002.0   896.85
# 10429      2227.0   897.58
# 10430      2068.0   888.62
# 10431      2076.0   889.74
#
# [5583 rows x 2 columns]

# %%
#Training the model
from sklearn.ensemble import IsolationForest
seed=12345
model11=IsolationForest(n_estimators=100, max_samples='auto', contamination=0.01, max_features=1.0, bootstrap=False, n_jobs=-1, random_state=42, verbose=0)
model11.fit(outlier_data)
# Out:
# IsolationForest(contamination=0.01, n_jobs=-1, random_state=42)

# %%
IF_predict=model11.predict(outlier_data)
IF_score=model11.score_samples(outlier_data)

# %%
IF_predictions = pd.DataFrame({"predicted_class": list(map(lambda IF: 1*(IF == -1), IF_predict)), "predict": IF_score})
IF_predictions
# Out:
#       predicted_class   predict
# 0                   0 -0.623186
# 1                   0 -0.642443
# 2                   0 -0.641585
# 3                   0 -0.631341
# 4                   0 -0.632556
# ...               ...       ...
# 5578                0 -0.469359
# 5579                0 -0.469699
# 5580                0 -0.492126
# 5581                0 -0.475728
# 5582                0 -0.475470
#
# [5583 rows x 2 columns]

# %%
outlier['anomaly']=IF_predict
outlier
# Out:
#        EPAssetsId  TotalDepth      TVD  anomaly
# 1         2593278      3607.0  1954.58        1
# 2         2579437      3502.0  1940.06        1
# 3         2591761      3491.0  1945.01        1
# 4         2587302      3578.0  1956.34        1
# 5         2600942      3659.0  1911.62        1
# ...           ...         ...      ...      ...
# 10425     2612600      2024.0   891.82        1
# 10428     2605004      2002.0   896.85        1
# 10429     2605001      2227.0   897.58        1
# 10430     2619591      2068.0   888.62        1
# 10431     2619592      2076.0   889.74        1
#
# [5583 rows x 4 columns]

# %%
outlier[outlier.anomaly==-1].count()
# Out:
# EPAssetsId    56
# TotalDepth    56
# TVD           56
# anomaly       56
# dtype: int64

# %%
well_cut_new=outlier[outlier.anomaly==1]
well_cut_new
# Out:
#        EPAssetsId  TotalDepth      TVD  anomaly
# 1         2593278      3607.0  1954.58        1
# 2         2579437      3502.0  1940.06        1
# 3         2591761      3491.0  1945.01        1
# 4         2587302      3578.0  1956.34        1
# 5         2600942      3659.0  1911.62        1
# ...           ...         ...      ...      ...
# 10425     2612600      2024.0   891.82        1
# 10428     2605004      2002.0   896.85        1
# 10429     2605001      2227.0   897.58        1
# 10430     2619591      2068.0   888.62        1
# 10431     2619592      2076.0   889.74        1
#
# [5527 rows x 4 columns]

# %%
new_data=pd.merge(well_cut,well_cut_new, on=['EPAssetsId','TotalDepth','TVD'])
#'EPAssetsId','TVD','WellProfile','WellType','LaheeClass','CurrentStatus','TotalDepth','Surf_Longitude','Surf_Latitude','KBElevation'

# %%
well_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9289 entries, 0 to 10432
# Data columns (total 89 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   EPAssetsId                 9289 non-null   int64
#  1   Province                   9289 non-null   object
#  2   LicenceNumber              9289 non-null   object
#  3   UWI                        9289 non-null   object
#  4   CurrentOperator            9289 non-null   object
#  5   CurrentOperatorParent      9289 non-null   int64
#  6   CurrentOperatorParentName  9289 non-null   object
#  7   Licensee                   9289 non-null   object
#  8   LicenseeParentCompany      9289 non-null   int64
#  9   LicenseeParentCompanyName  9289 non-null   object
#  10  LicenceDate                9289 non-null   object
#  11  CurrentStatus              9289 non-null   object
#  12  CurrentStatusStandardised  9289 non-null   object
#  13  WellType                   9289 non-null   object
#  14  WellTypeStandardised       9289 non-null   object
#  15  ConfidentialReleaseDate    7362 non-null   object
#  16  AbandonDate                0 non-null      float64
#  17  SurfAbandonDate            0 non-null      float64
#  18  WellName                   9289 non-null   object
#  19  Formation                  9289 non-null   object
#  20  Field                      9289 non-null   object
#  21  Pool                       9289 non-null   object
#  22  SurveySystem               9289 non-null   object
#  23  Surf_Location              9289 non-null   object
#  24  Surf_Township              9289 non-null   object
#  25  Surf_Meridian              9289 non-null   object
#  26  Surf_Range                 9289 non-null   object
#  27  Surf_Section               9289 non-null   object
#  28  Surf_LSD                   9289 non-null   object
#  29  Surf_Longitude             9289 non-null   float64
#  30  Surf_Latitude              9289 non-null   float64
#  31  Surf_TownshipRange         9289 non-null   object
#  32  Surf_QuarterUnit           9289 non-null   object
#  33  Surf_Unit                  9289 non-null   object
#  34  Surf_Block                 9289 non-null   object
#  35  Surf_NTSMapSheet           9289 non-null   object
#  36  Surf_Series                9289 non-null   object
#  37  Surf_Area                  9289 non-null   object
#  38  Surf_Sheet                 9289 non-null   object
#  39  Surf_QuarterSection        9289 non-null   object
#  40  BH_Location                9289 non-null   object
#  41  BH_TownshipRange           9289 non-null   object
#  42  BH_QuarterUnit             9289 non-null   object
#  43  BH_Unit                    9289 non-null   object
#  44  BH_Block                   9289 non-null   object
#  45  BH_NTSMapSheet             9289 non-null   object
#  46  BH_Series                  9289 non-null   object
#  47  BH_Area                    9289 non-null   object
#  48  BH_Sheet                   9289 non-null   object
#  49  BH_QuarterSection          7549 non-null   object
#  50  BH_Longitude               7549 non-null   float64
#  51  BH_Latitude                7549 non-null   float64
#  52  BH_Township                9289 non-null   object
#  53  BH_Meridian                9289 non-null   object
#  54  BH_Range                   9289 non-null   object
#  55  BH_Section                 9289 non-null   object
#  56  BH_LSD                     9289 non-null   object
#  57  GroundElevation            9281 non-null   float64
#  58  KBElevation                9289 non-null   float64
#  59  TotalDepth                 9289 non-null   float64
#  60  LaheeClass                 9289 non-null   object
#  61  Confidential               9289 non-null   object
#  62  SurfaceOwner               9289 non-null   object
#  63  OSArea                     7549 non-null   object
#  64  OSDeposit                  7549 non-null   object
#  65  DrillingContractor         9257 non-null   object
#  66  SpudDate                   9289 non-null   object
#  67  FinalDrillDate             7549 non-null   object
#  68  RigReleaseDate             9289 non-null   object
#  69  DaysDrilling               9283 non-null   float64
#  70  DrillMetresPerDay          9289 non-null   float64
#  71  TVD                        5583 non-null   float64
#  72  WellProfile                9289 non-null   object
#  73  Country                    9289 non-null   object
#  74  RegulatoryAgency           9289 non-null   object
#  75  PSACAreaCode               9289 non-null   object
#  76  PSACAreaName               9289 non-null   object
#  77  ProjectedDepth             8979 non-null   float64
#  78  StatusDate                 9289 non-null   object
#  79  StatusSource               9289 non-null   object
#  80  UnitID                     708 non-null    object
#  81  UnitName                   708 non-null    object
#  82  UnitFlag                   7549 non-null   object
#  83  Municipality               4110 non-null   object
#  84  CompletionDate             5850 non-null   object
#  85  Agent                      9289 non-null   object
#  86  _Completed`Flag            9289 non-null   int64
#  87  _Perf`Flag                 9289 non-null   int64
#  88  Match                      9289 non-null   object
# dtypes: float64(13), int64(5), object(71)
# memory usage: 6.4+ MB

# %% [markdown]
# # Whole-dataset

# %%
#Variables selection for the model
all_wells=well_cut[['EPAssetsId','TVD','Formation','WellProfile','WellTypeStandardised','TotalDepth','Surf_Longitude','Surf_Latitude','KBElevation']]
data_wells=all_wells[all_wells.TVD.notnull()]
data_wells.columns=['EPAssetsId','TVD','Formation','WellProfile','WellType','TotalDepth','Surf_Longitude','Surf_Latitude','KBElevation']
data_wells
# Out:
#        EPAssetsId      TVD Formation  WellProfile WellType  TotalDepth  \
# 1         2593278  1954.58   Montney   Horizontal      Oil      3607.0
# 2         2579437  1940.06   Montney   Horizontal      Oil      3502.0
# 3         2591761  1945.01   Montney   Horizontal      Oil      3491.0
# 4         2587302  1956.34   Montney   Horizontal      Oil      3578.0
# 5         2600942  1911.62   Montney   Horizontal      Oil      3659.0
# ...           ...      ...       ...          ...      ...         ...
# 10425     2612600   891.82    Viking  Directional      Oil      2024.0
# 10428     2605004   896.85    Viking   Horizontal      Oil      2002.0
# 10429     2605001   897.58    Viking   Horizontal      Oil      2227.0
# 10430     2619591   888.62    Viking  Directional      Oil      2068.0
# 10431     2619592   889.74    Viking  Directional      Oil      2076.0
#
#        Surf_Longitude  Surf_Latitude  KBElevation
# 1         -117.527042      54.737446        770.8
# 2         -117.559923      54.730864        759.4
# 3         -117.560141      54.730703        759.8
# 4         -117.561283      54.723339        767.7
# 5         -117.639433      54.787071        725.0
# ...               ...            ...          ...
# 10425     -111.146918      51.913412        784.8
# 10428     -111.183763      51.920839        785.8
# 10429     -111.183762      51.920983        785.5
# 10430     -111.199446      51.895504        777.7
# 10431     -111.199446      51.895432        777.7
#
# [5583 rows x 9 columns]

# %%
#Creating dummies for categorical variables WellProfile and WellType

all_profile_dummies = pd.get_dummies(data_wells.WellProfile, prefix='WellProfile').iloc[:,1:]
all_type_dummies = pd.get_dummies(data_wells.WellType, prefix='WellType').iloc[:,1:]
all_formation_dummies = pd.get_dummies(data_wells.Formation, prefix='Formation').iloc[:,1:]
#all_status_dummies = pd.get_dummies(data_wells.CurrentStatus, prefix='Status').iloc[:,1:]

df_all = pd.concat([data_wells,all_profile_dummies,all_formation_dummies,all_type_dummies], axis=1)
df_all
# Out:
#        EPAssetsId      TVD Formation  WellProfile WellType  TotalDepth  \
# 1         2593278  1954.58   Montney   Horizontal      Oil      3607.0
# 2         2579437  1940.06   Montney   Horizontal      Oil      3502.0
# 3         2591761  1945.01   Montney   Horizontal      Oil      3491.0
# 4         2587302  1956.34   Montney   Horizontal      Oil      3578.0
# 5         2600942  1911.62   Montney   Horizontal      Oil      3659.0
# ...           ...      ...       ...          ...      ...         ...
# 10425     2612600   891.82    Viking  Directional      Oil      2024.0
# 10428     2605004   896.85    Viking   Horizontal      Oil      2002.0
# 10429     2605001   897.58    Viking   Horizontal      Oil      2227.0
# 10430     2619591   888.62    Viking  Directional      Oil      2068.0
# 10431     2619592   889.74    Viking  Directional      Oil      2076.0
#
#        Surf_Longitude  Surf_Latitude  KBElevation  WellProfile_Horizontal  \
# 1         -117.527042      54.737446        770.8                       1
# 2         -117.559923      54.730864        759.4                       1
# 3         -117.560141      54.730703        759.8                       1
# 4         -117.561283      54.723339        767.7                       1
# 5         -117.639433      54.787071        725.0                       1
# ...               ...            ...          ...                     ...
# 10425     -111.146918      51.913412        784.8                       0
# 10428     -111.183763      51.920839        785.8                       1
# 10429     -111.183762      51.920983        785.5                       1
# 10430     -111.199446      51.895504        777.7                       0
# 10431     -111.199446      51.895432        777.7                       0
#
#        WellProfile_Vertical  Formation_Montney  Formation_Viking  WellType_Oil
# 1                         0                  1                 0             1
# 2                         0                  1                 0             1
# 3                         0                  1                 0             1
# 4                         0                  1                 0             1
# 5                         0                  1                 0             1
# ...                     ...                ...               ...           ...
# 10425                     0                  0                 1             1
# 10428                     0                  0                 1             1
# 10429                     0                  0                 1             1
# 10430                     0                  0                 1             1
# 10431                     0                  0                 1             1
#
# [5583 rows x 14 columns]

# %%
#Taking features and standardizing them
from sklearn.preprocessing import StandardScaler
#sec=df_all.iloc[:,6:]
#scale=StandardScaler()
#scaled=scale.fit_transform(sec)
#df_all_sc=pd.DataFrame(scaled)
#df_all_sc

# %%
#Extrating feature variables for the model (Normalised varibles)
#X=df_all1.iloc[:, 1:]
#y=df_all1.iloc[:, 0]
#X

# %%
#Extrating feature variables for the model (Normalised varibles)
X1=df_all.iloc[:, 5:]
y1=df_all.iloc[:, 1]
X1
# Out:
#        TotalDepth  Surf_Longitude  Surf_Latitude  KBElevation  \
# 1          3607.0     -117.527042      54.737446        770.8
# 2          3502.0     -117.559923      54.730864        759.4
# 3          3491.0     -117.560141      54.730703        759.8
# 4          3578.0     -117.561283      54.723339        767.7
# 5          3659.0     -117.639433      54.787071        725.0
# ...           ...             ...            ...          ...
# 10425      2024.0     -111.146918      51.913412        784.8
# 10428      2002.0     -111.183763      51.920839        785.8
# 10429      2227.0     -111.183762      51.920983        785.5
# 10430      2068.0     -111.199446      51.895504        777.7
# 10431      2076.0     -111.199446      51.895432        777.7
#
#        WellProfile_Horizontal  WellProfile_Vertical  Formation_Montney  \
# 1                           1                     0                  1
# 2                           1                     0                  1
# 3                           1                     0                  1
# 4                           1                     0                  1
# 5                           1                     0                  1
# ...                       ...                   ...                ...
# 10425                       0                     0                  0
# 10428                       1                     0                  0
# 10429                       1                     0                  0
# 10430                       0                     0                  0
# 10431                       0                     0                  0
#
#        Formation_Viking  WellType_Oil
# 1                     0             1
# 2                     0             1
# 3                     0             1
# 4                     0             1
# 5                     0             1
# ...                 ...           ...
# 10425                 1             1
# 10428                 1             1
# 10429                 1             1
# 10430                 1             1
# 10431                 1             1
#
# [5583 rows x 9 columns]

# %%
#Selecting the random set from the above analysis
from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.35, random_state=0)
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.22, random_state=0)

# %%
print('Training Features Shape:', X1_train.shape)
print('Training Labels Shape:', y1_train.shape)
print('Testing Features Shape:', X1_test.shape)
print('Testing Labels Shape:', y1_test.shape)
# Out:
# Training Features Shape: (4354, 9)
# Training Labels Shape: (4354,)
# Testing Features Shape: (1229, 9)
# Testing Labels Shape: (1229,)

# %% [markdown]
# # Random Regression-VIK

# %%
# Import the model 
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
# Instantiate model with 5000 decision trees
#rf_all = RandomForestRegressor(n_estimators = 5000, random_state = 0)
rf_all1 = RandomForestRegressor(n_estimators = 5000, random_state = 0)

# Train the model on training data

#rf_all.fit(X_train,y_train)
rf_all1.fit(X1_train,y1_train)

# %%
#rf_all_predictions=rf_all.predict(X_test)
rf_all1_predictions=rf_all1.predict(X1_test)

# %%
#print(rf_all.score(X_train,y_train))
print(rf_all1.score(X1_train,y1_train))

# %%
#print(rf_all.score(X_test,y_test))
print(rf_all1.score(X1_test,y1_test))

# %%
#error = np.sqrt(mean_squared_error(y_test,rf_all_predictions))
error1 = np.sqrt(mean_squared_error(y1_test,rf_all1_predictions))
#print(error)
print(error1)

# %%
fig1 = px.scatter(data_wells, x=y1_test, y=rf_all1_predictions)

fig1.show()

# %% [markdown]
# # Feature Importance

# %%
feature_list = list(X1.columns)

# %%
# Get numerical feature importances
impact = list(rf_all1.feature_importances_)
# List of tuples with variable and importance
feature_impact = [(X1, round(importance, 2)) for X1, importance in zip(feature_list, impact)]
# Sort the feature importances by most important first
feature_impact = sorted(feature_impact, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Impact: {}'.format(*pair)) for pair in feature_impact];
# Out:
# Variable: TotalDepth           Impact: 0.93
# Variable: WellType_Oil         Impact: 0.03
# Variable: Surf_Latitude        Impact: 0.02
# Variable: Surf_Longitude       Impact: 0.01
# Variable: KBElevation          Impact: 0.01
# Variable: WellProfile_Horizontal Impact: 0.0
# Variable: WellProfile_Vertical Impact: 0.0
# Variable: Lahee_Development    Impact: 0.0
# Variable: Lahee_Development Service Well Impact: 0.0
# Variable: Lahee_New Pool Wildcat Impact: 0.0
# Variable: Lahee_Outpost        Impact: 0.0
# Variable: Lahee_Re-entry       Impact: 0.0
# Variable: Status_Flowing       Impact: 0.0
# Variable: Status_Gas Lift      Impact: 0.0
# Variable: Status_Pumping       Impact: 0.0
# Variable: Status_Suspended     Impact: 0.0

# %% [markdown]
# # Preparing the prediction data

# %%
#Now getting the duv testing data to make predictions
test=well_cut[['EPAssetsId','TVD','WellProfile','WellTypeStandardised','LaheeClass','CurrentStatus','TotalDepth','Surf_Longitude','Surf_Latitude','KBElevation']]
test_data=test[well_cut.TVD.isnull()] #Getting the data where TVD need to be predicted
test_data.columns=['EPAssetsId','TVD','WellProfile','WellType','LaheeClass','CurrentStatus','TotalDepth','Surf_Longitude','Surf_Latitude','KBElevation']
test_data
# Out:
#        EPAssetsId  TVD  WellProfile WellType   LaheeClass CurrentStatus  \
# 0         2587301  NaN   Horizontal      Oil  Development      Gas Lift
# 8         2608978  NaN   Horizontal      Oil  Development       Flowing
# 14        2608702  NaN   Horizontal      Gas  Development       Flowing
# 15        2614267  NaN  Directional      Gas  Development       Flowing
# 17        2608700  NaN   Horizontal      Gas  Development       Flowing
# ...           ...  ...          ...      ...          ...           ...
# 10421     2593752  NaN   Horizontal      Oil  Development       Pumping
# 10423     2588281  NaN   Horizontal      Oil  Development       Pumping
# 10426     2588282  NaN   Horizontal      Oil  Development       Pumping
# 10427     2588283  NaN   Horizontal      Oil  Development     Suspended
# 10432     2621490  NaN  Directional      Oil  Development       Pumping
#
#        TotalDepth  Surf_Longitude  Surf_Latitude  KBElevation
# 0          3677.0     -117.529866      54.747632        764.8
# 8          3508.0     -117.482119      54.745328        807.4
# 14         6110.0     -116.965662      54.578063        787.0
# 15         6106.0     -116.965540      54.578117        787.0
# 17         5701.0     -116.965908      54.577954        787.0
# ...           ...             ...            ...          ...
# 10421      2060.0     -111.161530      51.912631        783.0
# 10423      1716.0     -111.175877      51.910109        782.8
# 10426      1737.0     -111.137825      51.910015        784.4
# 10427      1759.0     -111.161386      51.912631        782.9
# 10432      1976.0     -111.098455      51.959143        798.9
#
# [3706 rows x 10 columns]

# %%
#Creating dummies for categorical variables WellProfile and WellType

#well_formation_dummies_test = pd.get_dummies(test_data.Formation, prefix='Formation').iloc[:,1:]
all_profile_dummies_test = pd.get_dummies(test_data.WellProfile, prefix='WellProfile').iloc[:,1:]
all_type_dummies_test = pd.get_dummies(test_data.WellType, prefix='WellType').iloc[:,1:]
all_lahee_dummies_test = pd.get_dummies(test_data.LaheeClass, prefix='Lahee').iloc[:,1:]
all_status_dummies_test = pd.get_dummies(test_data.CurrentStatus, prefix='Status').iloc[:,1:]

test_all = pd.concat([test_data, all_profile_dummies_test,all_type_dummies_test,all_lahee_dummies_test,all_status_dummies_test], axis=1)
test_all
# Out:
#        EPAssetsId  TVD  WellProfile WellType   LaheeClass CurrentStatus  \
# 0         2587301  NaN   Horizontal      Oil  Development      Gas Lift
# 8         2608978  NaN   Horizontal      Oil  Development       Flowing
# 14        2608702  NaN   Horizontal      Gas  Development       Flowing
# 15        2614267  NaN  Directional      Gas  Development       Flowing
# 17        2608700  NaN   Horizontal      Gas  Development       Flowing
# ...           ...  ...          ...      ...          ...           ...
# 10421     2593752  NaN   Horizontal      Oil  Development       Pumping
# 10423     2588281  NaN   Horizontal      Oil  Development       Pumping
# 10426     2588282  NaN   Horizontal      Oil  Development       Pumping
# 10427     2588283  NaN   Horizontal      Oil  Development     Suspended
# 10432     2621490  NaN  Directional      Oil  Development       Pumping
#
#        TotalDepth  Surf_Longitude  Surf_Latitude  KBElevation  ...  \
# 0          3677.0     -117.529866      54.747632        764.8  ...
# 8          3508.0     -117.482119      54.745328        807.4  ...
# 14         6110.0     -116.965662      54.578063        787.0  ...
# 15         6106.0     -116.965540      54.578117        787.0  ...
# 17         5701.0     -116.965908      54.577954        787.0  ...
# ...           ...             ...            ...          ...  ...
# 10421      2060.0     -111.161530      51.912631        783.0  ...
# 10423      1716.0     -111.175877      51.910109        782.8  ...
# 10426      1737.0     -111.137825      51.910015        784.4  ...
# 10427      1759.0     -111.161386      51.912631        782.9  ...
# 10432      1976.0     -111.098455      51.959143        798.9  ...
#
#        WellType_Oil  Lahee_Development  Lahee_Development Service Well  \
# 0                 1                  1                               0
# 8                 1                  1                               0
# 14                0                  1                               0
# 15                0                  1                               0
# 17                0                  1                               0
# ...             ...                ...                             ...
# 10421             1                  1                               0
# 10423             1                  1                               0
# 10426             1                  1                               0
# 10427             1                  1                               0
# 10432             1                  1                               0
#
#        Lahee_New Pool Wildcat  Lahee_Outpost  Lahee_Re-entry  Status_Flowing  \
# 0                           0              0               0               0
# 8                           0              0               0               1
# 14                          0              0               0               1
# 15                          0              0               0               1
# 17                          0              0               0               1
# ...                       ...            ...             ...             ...
# 10421                       0              0               0               0
# 10423                       0              0               0               0
# 10426                       0              0               0               0
# 10427                       0              0               0               0
# 10432                       0              0               0               0
#
#        Status_Gas Lift  Status_Pumping  Status_Suspended
# 0                    1               0                 0
# 8                    0               0                 0
# 14                   0               0                 0
# 15                   0               0                 0
# 17                   0               0                 0
# ...                ...             ...               ...
# 10421                0               1                 0
# 10423                0               1                 0
# 10426                0               1                 0
# 10427                0               0                 1
# 10432                0               1                 0
#
# [3706 rows x 22 columns]

# %%
#Taking features and standardizing them
from sklearn.preprocessing import StandardScaler
#test=test_all.iloc[:,6:]
#scale_test=StandardScaler()
#scaled_test=scale_test.fit_transform(test)
#test_pred_sc=pd.DataFrame(scaled_test)
#test_pred_sc

# %%
test=test_all.iloc[:,6:]

# %%
#Prediction from random forest
predicted_test=rf_all1.predict(test)

# %%
#Putting the predicted TVD in the dataframe as TVD_predicted
test_all['TVD_predicted_RF']=predicted_test
test_all
# Out:
#        EPAssetsId  TVD  WellProfile WellType   LaheeClass CurrentStatus  \
# 0         2587301  NaN   Horizontal      Oil  Development      Gas Lift
# 8         2608978  NaN   Horizontal      Oil  Development       Flowing
# 14        2608702  NaN   Horizontal      Gas  Development       Flowing
# 15        2614267  NaN  Directional      Gas  Development       Flowing
# 17        2608700  NaN   Horizontal      Gas  Development       Flowing
# ...           ...  ...          ...      ...          ...           ...
# 10421     2593752  NaN   Horizontal      Oil  Development       Pumping
# 10423     2588281  NaN   Horizontal      Oil  Development       Pumping
# 10426     2588282  NaN   Horizontal      Oil  Development       Pumping
# 10427     2588283  NaN   Horizontal      Oil  Development     Suspended
# 10432     2621490  NaN  Directional      Oil  Development       Pumping
#
#        TotalDepth  Surf_Longitude  Surf_Latitude  KBElevation  ...  \
# 0          3677.0     -117.529866      54.747632        764.8  ...
# 8          3508.0     -117.482119      54.745328        807.4  ...
# 14         6110.0     -116.965662      54.578063        787.0  ...
# 15         6106.0     -116.965540      54.578117        787.0  ...
# 17         5701.0     -116.965908      54.577954        787.0  ...
# ...           ...             ...            ...          ...  ...
# 10421      2060.0     -111.161530      51.912631        783.0  ...
# 10423      1716.0     -111.175877      51.910109        782.8  ...
# 10426      1737.0     -111.137825      51.910015        784.4  ...
# 10427      1759.0     -111.161386      51.912631        782.9  ...
# 10432      1976.0     -111.098455      51.959143        798.9  ...
#
#        Lahee_Development  Lahee_Development Service Well  \
# 0                      1                               0
# 8                      1                               0
# 14                     1                               0
# 15                     1                               0
# 17                     1                               0
# ...                  ...                             ...
# 10421                  1                               0
# 10423                  1                               0
# 10426                  1                               0
# 10427                  1                               0
# 10432                  1                               0
#
#        Lahee_New Pool Wildcat  Lahee_Outpost  Lahee_Re-entry  Status_Flowing  \
# 0                           0              0               0               0
# 8                           0              0               0               1
# 14                          0              0               0               1
# 15                          0              0               0               1
# 17                          0              0               0               1
# ...                       ...            ...             ...             ...
# 10421                       0              0               0               0
# 10423                       0              0               0               0
# 10426                       0              0               0               0
# 10427                       0              0               0               0
# 10432                       0              0               0               0
#
#        Status_Gas Lift  Status_Pumping  Status_Suspended  TVD_predicted_RF
# 0                    1               0                 0        1937.54750
# 8                    0               0                 0        1874.57162
# 14                   0               0                 0        3027.46249
# 15                   0               0                 0        3026.13510
# 17                   0               0                 0        3025.47306
# ...                ...             ...               ...               ...
# 10421                0               1                 0         890.75178
# 10423                0               1                 0         891.41937
# 10426                0               1                 0         891.28981
# 10427                0               0                 1         909.81486
# 10432                0               1                 0         893.04266
#
# [3706 rows x 23 columns]

# %%
#import statistics as sc
#back_test=predicted_test*data_wells['TVD'].std()+data_wells['TVD'].mean()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Total Depth')
plt.ylabel('TVD')
plt.scatter(new_data['TotalDepth'], new_data['TVD'], color='purple')
plt.scatter(test_all['TotalDepth'], predicted_test, color='red')

# %%
fig1 = px.scatter(data_wells, x="TotalDepth", y="TVD")

fig1.show()
# Out:
# <div>
#
#
#             <div id="633b1950-d56b-4682-b683-4967f16be072" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("633b1950-d56b-4682-b683-4967f16be072")) {
#                     Plotly.newPlot(
#                         '633b1950-d56b-4682-b683-4967f16be072',
#                         [{"hovertemplate": "TotalDepth=%{x}<br>TVD=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [3607.0, 3502.0, 3491.0, 3578.0, 3659.0, 4501.0, 5776.0, 3741.0, 3574.0, 6803.0, 7770.0, 7617.0, 5787.0, 5800.0, 5670.0, 5577.0, 4207.0, 4296.0, 4640.0, 4468.0, 4379.0, 4596.0, 4700.0, 4024.0, 4150.0, 4503.0, 4537.0, 3840.0, 7131.0, 6828.0, 5430.0, 6437.0, 6828.0, 5974.0, 4378.0, 5710.0, 5973.0, 6383.0, 6086.0, 5425.0, 6442.0, 6434.0, 6880.0, 6875.0, 6932.0, 6479.0, 6017.0, 6313.0, 6691.0, 6250.0, 6226.0, 6210.0, 6190.0, 6379.0, 3925.0, 5953.0, 6010.0, 5555.0, 6172.0, 5433.0, 6315.0, 6162.0, 7180.0, 5152.0, 5490.0, 5765.0, 5742.0, 6221.0, 6371.0, 5208.0, 5457.0, 5485.0, 5700.0, 4873.0, 4690.0, 5993.0, 6237.0, 6263.0, 6553.0, 6241.0, 5922.0, 6023.0, 6632.0, 4781.0, 4760.0, 4716.0, 5349.0, 5987.0, 5006.0, 4824.0, 3528.0, 3570.0, 3516.0, 3562.0, 3524.0, 3494.0, 3643.0, 4700.0, 4678.0, 6662.0, 6414.0, 6750.0, 6796.0, 3475.0, 3413.0, 3404.0, 3429.0, 3441.0, 3430.0, 3437.0, 4336.0, 4476.0, 4775.0, 5994.0, 4907.0, 5899.0, 5620.0, 4766.0, 4933.0, 4435.0, 4493.0, 3780.0, 5730.0, 5742.0, 6142.0, 6700.0, 6063.0, 6174.0, 7223.0, 7096.0, 6828.0, 6932.0, 6890.0, 5802.0, 5774.0, 5831.0, 5866.0, 5727.0, 5866.0, 6048.0, 6288.0, 6954.0, 7083.0, 6726.0, 6408.0, 6186.0, 5804.0, 5822.0, 5824.0, 5400.0, 4631.0, 3923.0, 3856.0, 4029.0, 6798.0, 4580.0, 4638.0, 4755.0, 4662.0, 3868.0, 3817.0, 3843.0, 3622.0, 5278.0, 5820.0, 5769.0, 6014.0, 5815.0, 6011.0, 5910.0, 4904.0, 6095.0, 5466.0, 5903.0, 5128.0, 5464.0, 5120.0, 6006.0, 6210.0, 4950.0, 5196.0, 5460.0, 5680.0, 5337.0, 4837.0, 5800.0, 5865.0, 5989.0, 5789.0, 5865.0, 5869.0, 4229.0, 4917.0, 6213.0, 5881.0, 5444.0, 5670.0, 4848.0, 5768.0, 6577.0, 6407.0, 6400.0, 6580.0, 6751.0, 4812.0, 5440.0, 5439.0, 5685.0, 5587.0, 6774.0, 5508.0, 5571.0, 6568.0, 6420.0, 6470.0, 6519.0, 6525.0, 5602.0, 5792.0, 5540.0, 5751.0, 5653.0, 5554.0, 5552.5, 6348.0, 6260.0, 5202.0, 5483.0, 5406.0, 5432.0, 5613.0, 5979.0, 5840.0, 4154.0, 4384.0, 4381.0, 7402.0, 4910.0, 4782.0, 4972.0, 4549.0, 4818.0, 4195.6, 3382.0, 4118.0, 3526.0, 3703.0, 3635.0, 3620.0, 3654.0, 4105.0, 4523.0, 3780.0, 4230.0, 4175.0, 4025.0, 4298.0, 4818.0, 4763.0, 4614.0, 3640.0, 3680.0, 3662.0, 5100.0, 4917.0, 5401.0, 5211.0, 5173.0, 5268.0, 5585.0, 4580.0, 4932.0, 5030.0, 4605.0, 4561.0, 4640.0, 4509.0, 4595.0, 4684.0, 4795.0, 4798.0, 5332.0, 5332.0, 5321.0, 5413.0, 4580.0, 4732.0, 5840.0, 5901.0, 4700.0, 5226.0, 5082.0, 4948.0, 4919.0, 5197.0, 4818.0, 5001.0, 5965.0, 5206.0, 5350.0, 5780.0, 5485.0, 5270.0, 5474.0, 5305.0, 5320.0, 6050.0, 5928.0, 6319.0, 6344.0, 6091.0, 6200.0, 5143.0, 6030.0, 6435.0, 6236.0, 6588.0, 5712.0, 5761.0, 5705.0, 6025.0, 6054.0, 5274.0, 5095.0, 5700.0, 6145.0, 5960.0, 4850.0, 5106.0, 5285.0, 5690.0, 6585.0, 6497.0, 6034.0, 5800.0, 5875.0, 6377.0, 6465.0, 6388.0, 6419.0, 6429.0, 6281.0, 5920.0, 6205.0, 5639.0, 6146.0, 6099.0, 6076.0, 6143.0, 6332.0, 6013.0, 6063.0, 5308.0, 5569.0, 5370.0, 5390.0, 5474.0, 5485.0, 5385.0, 5578.0, 5531.0, 5650.0, 5607.0, 4345.0, 4430.0, 4438.0, 4315.0, 4400.0, 4500.0, 5871.0, 5985.0, 5517.0, 5782.0, 6064.0, 6006.0, 6150.0, 6275.0, 6080.0, 5409.0, 6210.0, 6279.0, 5848.0, 7310.0, 5838.0, 5878.0, 5762.0, 4720.0, 5260.0, 5012.0, 4855.0, 4190.0, 3779.0, 5073.0, 5500.0, 5116.0, 4935.0, 6575.0, 6726.0, 5358.0, 5446.0, 5636.0, 5272.0, 4711.0, 4646.0, 6121.0, 5963.0, 5990.0, 5910.0, 5877.0, 5843.0, 5526.0, 6950.0, 6060.0, 5825.0, 5780.0, 5350.0, 6545.0, 6010.0, 6437.0, 5690.0, 5282.0, 5457.0, 5236.0, 7848.0, 7356.0, 5730.0, 5400.0, 5500.0, 5975.0, 5785.0, 5625.0, 5940.0, 6225.0, 6580.0, 6206.0, 4806.0, 5267.0, 4752.0, 4140.0, 4033.0, 4123.0, 4072.0, 4127.0, 4111.0, 5473.0, 5465.0, 5470.0, 5425.0, 6580.0, 5830.0, 5895.0, 4283.5, 5001.0, 5308.3, 5478.0, 5176.0, 6050.0, 5780.0, 5652.0, 5020.0, 5355.0, 5208.0, 5580.0, 6400.0, 5044.0, 5109.0, 5127.0, 5290.0, 5715.0, 5339.0, 5 ...

# %% [markdown]
# # Exporting the data

# %%
#Getting the data from the submission list for the EPAssetsID
sub_list=pd.read_csv('Submission_Sample.csv')

# %%
#Merging the test data and submission data to get the required predicted TVD's
data_merge=pd.merge(sub_list,test_all, on='EPAssetsId')
data_merge

# %%
#Exporting the results to excel
data_merge.to_csv('Submission 12W.csv')
